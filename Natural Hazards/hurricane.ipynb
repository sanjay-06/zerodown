# %%
import shapefile
data = shapefile.Reader("IBTrACS.ALL.list.v04r00.points.shp")

# %%
data.bbox
# Out:
# [-180.0, -68.5, 180.0, 83.01000213623047]

# %%
import pandas as pd
df_fields = pd.DataFrame(data.fields[1:])

# %%
df_records = pd.DataFrame(data.records())

# %%
df_records.columns=[i for i in df_fields[0]]

# %%
df_records.head()
# Out:
#              SID  SEASON  NUMBER BASIN SUBBASIN       NAME  \
# 0  1842298N11080    1842       1    NI       BB  NOT_NAMED
# 1  1842298N11080    1842       1    NI       BB  NOT_NAMED
# 2  1842298N11080    1842       1    NI       BB  NOT_NAMED
# 3  1842298N11080    1842       1    NI       BB  NOT_NAMED
# 4  1842298N11080    1842       1    NI       BB  NOT_NAMED
#
#               ISO_TIME NATURE    LAT    LON  ...  USA_SEA_SE  USA_SEA_SW  \
# 0  1842-10-25 03:00:00     NR  10.90  80.30  ...         NaN         NaN
# 1  1842-10-25 06:00:00     NR  10.87  79.83  ...         NaN         NaN
# 2  1842-10-25 09:00:00     NR  10.84  79.35  ...         NaN         NaN
# 3  1842-10-25 12:00:00     NR  10.82  78.88  ...         NaN         NaN
# 4  1842-10-25 15:00:00     NR  10.80  78.40  ...         NaN         NaN
#
#   USA_SEA_NW STORM_SPD  STORM_DR  year month day hour  min
# 0        NaN       9.0     266.0  1842    10  25    3    0
# ...

# %%
data.records()
# Out:
# [Record #0: ['1842298N11080', 1842, 1, 'NI', 'BB', 'NOT_NAMED', '1842-10-25 03:00:00', 'NR', 10.9, 80.3, None, None, '', 'main', 43, 0, '__________O___', '', '', None, None, '', '', None, None, -5, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '', None, None, None, None, '', None, None, -999.9, None, None, None, None, None, None, None, -999.9, -999.9, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, -999.9, -999.9, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, '', None, None, 10.9, 80.3, 7, None, None, None, None, None, None, None, None, None, '', None, None, None, None, '', None, None, None, None, None, None, None, None, None, None, None,
# ...

# %%
df=df_records[df_records['SEASON']==2022]

# %%
df
# Out:
#                   SID  SEASON  NUMBER BASIN SUBBASIN       NAME  \
# 704073  2021326S13108    2022      93    SI       WA      PADDY
# 704074  2021326S13108    2022      93    SI       WA      PADDY
# 704075  2021326S13108    2022      93    SI       WA      PADDY
# 704076  2021326S13108    2022      93    SI       WA      PADDY
# 704077  2021326S13108    2022      93    SI       WA      PADDY
# ...               ...     ...     ...   ...      ...        ...
# 705119  2022083S13076    2022      19    SI       MM     HALIMA
# 705120  2022083S13076    2022      19    SI       MM     HALIMA
# 705121  2022090N12109    2022      20    WP       MM  NOT_NAMED
# 705122  2022090N12109    2022      20    WP       MM  NOT_NAMED
# 705123  2022090N12109    2022      20    WP       MM  NOT_NAMED
#
#                    ISO_TIME NATURE    LAT     LON  ...  USA_SEA_SE  \
# 704073  2021-11-22 06:00:00     TS -13.25  108.20  ...         NaN
# ...
