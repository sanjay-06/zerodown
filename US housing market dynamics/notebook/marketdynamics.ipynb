# %%
import pandas as pd
 
df = pd.read_csv('weekly_market_2017_2022.tsv',sep='\t')

# %%
df.head()
# Out:
#    region_id  region_type_id           region_name region_type period_begin  \
# 0        441               5    Brevard County, FL      county   2021-04-12
# 1        441               5    Brevard County, FL      county   2019-03-18
# 2        682               5    Caribou County, ID      county   2017-03-13
# 3        155               5  Jefferson County, AL      county   2018-03-26
# 4        441               5    Brevard County, FL      county   2019-07-29
#
#    period_end duration  total_homes_sold  total_homes_sold_yoy  \
# 0  2021-04-18  1 weeks             334.0              0.629268
# 1  2019-03-24  1 weeks             248.0             -0.057034
# 2  2017-03-19  1 weeks               1.0                   NaN
# 3  2018-04-01  1 weeks             283.0              0.092664
# 4  2019-08-04  1 weeks             364.0              0.120000
#
#    average_homes_sold  ...  average_adjustment_average_homes_sold  \
# ...

# %%
col1 = df.filter(items = ['region_name','region_type','period_begin','period_end','median_sale_price','months_of_supply','total_new_listings','pending_sales'])
col1 = col1.dropna()
Quartile = {'01' : 'Q1', '02' : 'Q1', '03': 'Q1', '04': 'Q2' ,'05' : 'Q2', '06' : 'Q2', '07': 'Q3', '08': 'Q3', '09' : 'Q3', '10' : 'Q4', '11': 'Q4', '12': 'Q4'  }
filter1 = col1['period_end'].str.split("-",expand = True)
filter2 = filter1.replace({1: Quartile})
filter3 = filter1[0] + "-" + filter2[1]
col1['Quartile'] = filter3
col1.head()
# Out:
#             region_name region_type period_begin  period_end  \
# 0    Brevard County, FL      county   2021-04-12  2021-04-18
# 1    Brevard County, FL      county   2019-03-18  2019-03-24
# 3  Jefferson County, AL      county   2018-03-26  2018-04-01
# 4    Brevard County, FL      county   2019-07-29  2019-08-04
# 5    Brevard County, FL      county   2021-11-08  2021-11-14
#
#    median_sale_price  months_of_supply  total_new_listings  pending_sales  \
# 0           285000.0          9.796407               283.0          284.0
# 1           213495.0         21.233871               291.0          147.0
# 3           184900.0         12.176678               216.0          182.0
# 4           235000.0         12.912088               296.0          219.0
# 5           312000.0         11.570370               330.0          243.0
#
#   Quartile
# 0  2021-Q2
# 1  2019-Q1
# 3  2018-Q2
# 4  2019-Q3
# 5  2021-Q4

# %%
from pymongo import MongoClient
from pprint import pprint
client = MongoClient("mongodb+srv://sanjay:1234@cluster0.gxmvm.mongodb.net/US_Housing?retryWrites=true&w=majority")
dbs = client["US_Housing"]
metric = dbs["Metric_Analysis"] 
price = dbs["Price_Drops"]

# %%
col2 = df.filter(items = ['region_name','region_type','period_begin','period_end','total_homes_sold_with_price_drops','price_drops','percent_total_price_drops_of_inventory'])
col2 = col2.dropna()
Quartile = {'01' : 'Q1', '02' : 'Q1', '03': 'Q1', '04': 'Q2' ,'05' : 'Q2', '06' : 'Q2', '07': 'Q3', '08': 'Q3', '09' : 'Q3', '10' : 'Q4', '11': 'Q4', '12': 'Q4'  }
filter1 = col2['period_end'].str.split("-",expand = True)
filter2 = filter1.replace({1: Quartile})
filter3 = filter1[0] + "-" + filter2[1]
col2['Quartile'] = filter3
col2.head()
# Out:
#             region_name region_type period_begin  period_end  \
# 0    Brevard County, FL      county   2021-04-12  2021-04-18
# 1    Brevard County, FL      county   2019-03-18  2019-03-24
# 3  Jefferson County, AL      county   2018-03-26  2018-04-01
# 4    Brevard County, FL      county   2019-07-29  2019-08-04
# 5    Brevard County, FL      county   2021-11-08  2021-11-14
#
#    total_homes_sold_with_price_drops  price_drops  \
# 0                               66.0         64.0
# 1                                0.0          3.0
# 3                               83.0         71.0
# 4                                2.0         10.0
# 5                               64.0         94.0
#
#    percent_total_price_drops_of_inventory Quartile
# 0                                0.022016  2021-Q2
# 1                                0.000602  2019-Q1
# 3                                0.022576  2018-Q2
# 4                                0.002327  2019-Q3
# ...

# %%
price.insert_many(col2.to_dict('records'))

# %%
db = dbs["Metric_Analysis"]
select2="median_sale_price"
query={"region_type":"county","region_name":"Brevard County, FL"}
x=db.aggregate([{
    "$group" : 
        {"_id" : {
            "region_name": "$region_name",
            "Quartile": "$Quartile",
        }, 
         "metric_avg" : { "$avg" : "$"+select2 }
         }},
         { "$limit" : 10 }
    ])
print([i for i in x])
# Out:
# [{'_id': {'region_name': 'Wilkin County, MN', 'Quartile': '2017-Q2'}, 'metric_avg': 119000.0}, {'_id': {'region_name': 'Buffalo, NY metro area', 'Quartile': '2019-Q3'}, 'metric_avg': 167529.25897435896}, {'_id': {'region_name': 'Medina County, OH', 'Quartile': '2020-Q1'}, 'metric_avg': 207767.89487179488}, {'_id': {'region_name': 'Le Flore County, OK', 'Quartile': '2017-Q4'}, 'metric_avg': 113595.56800000001}, {'_id': {'region_name': 'Honolulu County, HI', 'Quartile': '2018-Q1'}, 'metric_avg': 570858.2083333334}, {'_id': {'region_name': 'Augusta, ME metro area', 'Quartile': '2019-Q3'}, 'metric_avg': 172251.85897435897}, {'_id': {'region_name': 'Duchesne County, UT', 'Quartile': '2020-Q2'}, 'metric_avg': 156889.44444444444}, {'_id': {'region_name': 'Wright County, MN', 'Quartile': '2018-Q4'}, 'metric_avg': 255608.11025641026}, {'_id': {'region_name': 'Scott County, TN', 'Quartile': '2019-Q2'}, 'metric_avg': 131360.28235294117}, {'_id': {'region_name': 'Cumberland County, NJ', 'Quartil
# ...

# %%
metricaggregate=db.aggregate([{
    "$group" : 
        {"_id" : {
            "region_type": "$county",
            "Quartile": "$Quartile",

        }, 
        
         "metric_avg" : { "$avg" : "$total_new_listings" }
         }},
    ])

# %%
x=[]
y1=[]

for aggregate in metricaggregate:
    q=str(aggregate['_id']['Quartile'])
    x.append(q)
    y1.append(aggregate['metric_avg'])

# %%
x,y1
# Out:
# (['2021-Q2',
#   '2019-Q3',
#   '2017-Q1',
#   '2018-Q1',
#   '2022-Q1',
#   '2021-Q1',
#   '2017-Q3',
#   '2020-Q4',
#   '2019-Q1',
#   '2017-Q2',
#   '2021-Q3',
#   '2018-Q3',
#   '2017-Q4',
#   '2020-Q1',
#   '2020-Q2',
#   '2019-Q2',
#   '2018-Q2',
#   '2021-Q4',
#   '2018-Q4',
#   '2019-Q4',
#   '2020-Q3'],
#  [748.6657711972467,
#   774.5322458167223,
#   383.19521651130304,
#   592.2974607586142,
#   483.24809695649213,
#   554.5099527196154,
#   800.8905943320295,
#   699.6973192940986,
#   593.0038765834186,
#   844.7083594061096,
#   776.9090296990917,
#   804.9277037717552,
#   632.8754107083472,
#   580.3511511879354,
#   655.2060339495567,
#   832.3232763330419,
#   841.4463427879193,
#   627.9385333135333,
#   640.0847407281677,
#   626.053985110424,
#   775.5873711992962])

# %%
metricaggregate=db.distinct("region_name")

for x in metricaggregate:
    print(x)
# Out:
# Abbeville County, SC
# Aberdeen, WA metro area
# Abilene, TX metro area
# Ada, OK metro area
# Adair County, IA
# Adair County, OK
# Adams County, CO
# Adams County, ID
# Adams County, MS
# Adams County, OH
# Adams County, PA
# Adams County, WA
# Adams County, WI
# Addison County, VT
# Adrian, MI metro area
# Aiken County, SC
# Aitkin County, MN
# Akron, OH metro area
# Alachua County, FL
# Alamance County, NC
# Alameda County, CA
# Alamosa County, CO
# Albany County, NY
# Albany, GA metro area
# Albany, NY metro area
# Albany, OR metro area
# Albemarle, NC metro area
# Albert Lea, MN metro area
# Albertville, AL metro area
# Alcorn County, MS
# Alexander County, NC
# Alexandria, MN metro area
# Alexandria, VA
# Alice, TX metro area
# All Redfin Metros
# Allegan County, MI
# Allegany County, MD
# Allegany County, NY
# Alleghany County, NC
# Allegheny County, PA
# Allen County, OH
# Allendale County, SC
# Allentown, PA metro area
# Alma, MI metro area
# Alpine County, CA
# ...

# %%
metric.insert_many(col1.to_dict('records'))

# %%
x=db.find({"region_name":"Brevard County, FL"})
for y in x:
    print(y)
# Out:
# {'_id': ObjectId('62481c411fa9b4336b5e9a33'), 'region_name': 'Brevard County, FL', 'region_type': 'county', 'period_begin': '2021-04-12', 'period_end': '2021-04-18', 'total_homes_sold_with_price_drops': 66.0, 'price_drops': 64.0, 'percent_total_price_drops_of_inventory': 0.022015823873409, 'Quartile': '2021-Q2'}
# {'_id': ObjectId('62481c411fa9b4336b5e9a34'), 'region_name': 'Brevard County, FL', 'region_type': 'county', 'period_begin': '2019-03-18', 'period_end': '2019-03-24', 'total_homes_sold_with_price_drops': 0.0, 'price_drops': 3.0, 'percent_total_price_drops_of_inventory': 0.0006016847172081, 'Quartile': '2019-Q1'}
# {'_id': ObjectId('62481c411fa9b4336b5e9a36'), 'region_name': 'Brevard County, FL', 'region_type': 'county', 'period_begin': '2019-07-29', 'period_end': '2019-08-04', 'total_homes_sold_with_price_drops': 2.0, 'price_drops': 10.0, 'percent_total_price_drops_of_inventory': 0.0023272050267628, 'Quartile': '2019-Q3'}
# ...
